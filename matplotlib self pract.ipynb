# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]; plt.scatter(x,y, c = ['orange', 'blue', 'yellow', 'black', 'green'], s= [100,500,1000,2000,4000], alpha = 1)
plt.xscale('log')
plt.grid()
plt.show()
plt.clf()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]; plt.plot(x,y)
plt.xlabel('year')
plt.ylabel('population')
plt.yticks(range(1,11), b )
plt.show()

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]; plt.hist(x, bins = 3); plt.show()

# %%
a = list(range(1,11))

# %%
a
b = []

# %%
for A in a:
    B = str(A)+'b'
    b.append(B)

# %%
b
# Out:
# ['1b', '2b', '3b', '4b', '5b', '6b', '7b', '8b', '9b', '10b']
