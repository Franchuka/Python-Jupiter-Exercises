# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### Data Visualization
# Data visualization is the process of visualizing data in order to identify important patterns in the data that can be used for organizational decision making. Visualizing data graphically can reveal trends that otherwise may remain hidden from the naked eye.
#
# Data visualization is a precursor to many important processes such as Data Science, Machine Learning, Business Intelligence, and Data Analytics. Data visualization is, doubtless, one of the most important skillsets of the 21st century for a variety of jobs.

# %% [markdown]
# ### Data Visualization via Matplotlib
# In this section, we will start a formal discussion about Matplotlib, which is one of the most commonly and frequently used Python libraries for data visualization. Matplotlib is so popular that various advanced data visualization libraries such as Seaborn use Matplotlib as the underlying data visualization library.
#
# Matplotlib allows you to create reproducible figures programmatically. Let's learn how to use it! Before continuing this lecture, I encourage you just to explore the official Matplotlib web page: https://matplotlib.org/stable/index.html

# %% [markdown]
# Import the `matplotlib.pyplot` module under the name `plt` (the tidy way):

# %%
import matplotlib.pyplot as plt

# %%
# This makes the plots appear in the Jupyter notebook
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Procedural Format
plt.plot(x,y)
plt.xlabel('Normal Values') # Label on the x axis
plt.ylabel('Squares of X') # Label on the y axis
plt.title('Square graph') # Title of the graph
# Out:
# Text(0.5, 1.0, 'Square graph')

# %% [markdown]
# #### Creating Multiplots on Same Canvas

# %%
plt.subplot(1, 2, 1) #the first arg shows the number of rows, 2nd shows d number of columns, 
plt.plot(x, y, 'r') #3rd dets which graph you plotting on
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g')

# %% [markdown]
# ### Matplotlib Object Oriented Method
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# %%
fig1 = plt.figure()
axes1 = fig1.add_axes([0.1, 0.1, 1, 1]) # left, bottom, width, height (range 0 to 1)
axes1.plot(x, y, 'r')
axes1.set_xlabel('Values')
axes1.set_ylabel('Square of Values')
axes1.set_title('Square Graph')

axes2 = fig1.add_axes([0.2, 0.5, 0.3, 0.3])
axes2.plot(y, x, 'b')
axes2.set_xlabel('Values')
axes2.set_ylabel('Square of Values')
axes2.set_title('Square Graph')
# Out:
# Text(0.5, 1.0, 'Square Graph')

# %% [markdown]
# ### subplots()
# The plt.subplots() object will act as a more automatic axes manager

# %%
# Use similar to plt.figure() except use tuple unpacking to grab fig and axes
fig, axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')

# %%
fig, axes = plt.subplots(nrows=2, ncols=3)


plt.tight_layout() # to prevent labels from overlapping

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
fig, axes = plt.subplots(nrows=2, ncols=3)
s = [['Title1', 'Title2', 'Title3'], ['Title4', 'Title5', 'Title6']]
for i in range(len(axes)):
    for j in range(len(axes[0])):
        axes[i][j].plot(x, y, 'r')
        axes[i][j].set_title(s[i][j])
plt.tight_layout()

# %%
axes[0]
# Out:
# <AxesSubplot:title={'center':'Title'}, xlabel='X', ylabel='Y'>

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).
#
# For example:

# %%
fig = plt.figure(figsize=(5,2))
axes1 = fig.add_axes([0, 0, 1, 1])

# %%
fig, axes = plt.subplots(figsize=(12, 3), dpi=100)

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.
#
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %%
fig.savefig('filename.pdf')

# %%
fig.savefig('filename2.png', dpi=1000)

# %% [markdown]
# ______
# ## Legends, labels and titles

# %% [markdown]
# Now that we have covered the basics of how to create a figure canvas and add axes instances to the canvas, let's look at how decorate a figure with titles, axis labels, and legends.

# %% [markdown]
# ### Legends
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure:

# %%
fig3 = plt.figure()

ax = fig3.add_axes([0, 0, 1, 1])
ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="X**3")
ax.legend(loc=9)

# %% [markdown]
# The **legend** function takes an optional keyword argument **loc** that can be used to specify where in the figure the legend is to be drawn. The allowed values of **loc** are numerical codes for the various places the legend can be drawn. See the [documentation page](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html?highlight=legends) for details. Some of the most common **loc** values are:

# %%
# Lots of options....

ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner

# .. many more options are available

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# Matplotlib gives you *a lot* of options for customizing colors, linewidths, and linetypes.
#
# There is the basic MATLAB like syntax (which I would suggest you avoid using for more clairty sake:

# %% [markdown]
# ### Colors with MatLab like syntax
# With matplotlib, we can define the colors of lines and other graphical elements in a number of ways. First of all, we can use the MATLAB-like syntax where `'b'` means blue, `'g'` means green, etc. The MATLAB API for selecting line styles are also supported: where, for example, 'b.-' means a blue line with dots:

# %%
fig4 = plt.figure()

ax = fig4.add_axes([0, 0, 0.5, 0.5])
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# ### Colors with the color= parameter
# We can also define colors by their names or RGB hex codes and optionally provide an alpha value using the `color` and `alpha` keyword arguments. Alpha indicates opacity.

# %%
fig5, ax = plt.subplots()
ax.plot(x, x+1, color="pink")
ax.plot(x, x+2, color="#8B008B")

# %% [markdown]
# ### Line and marker styles
# To change the line width, we can use the `linewidth` or `lw` keyword argument. The line style can be selected using the `linestyle` or `ls` keyword arguments:

# %%
fig6, ax1 = plt.subplots(figsize=(10,6))

ax1.plot(x, x+1, color='red', linewidth=0.25)
ax1.plot(x, x+2, color='red', linewidth=0.50)
ax1.plot(x, x+3, color='red', linewidth=1)
ax1.plot(x, x+4, color='red', linewidth=2)

# possible linestype options ‘-‘, ‘--’, ‘-.’, ‘:’
ax1.plot(x, x+5, color='green', lw=2, linestyle='-')
ax1.plot(x, x+6, color='green', lw=2, linestyle='--')
ax1.plot(x, x+7, color='green', lw=2, linestyle='-.')
ax1.plot(x, x+8, color='green', lw=2, linestyle=':')

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax1.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+', markersize=10)
ax1.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax1.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax1.plot(x, x+12, color="blue", lw=3, ls='--', marker='1', markersize=10)
