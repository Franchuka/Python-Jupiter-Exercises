# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ages = [47,50, 12, 15]
for i, age in enumerate(ages):
    if age<18:
        is_minor = True
        age_list[i]

# %%
nut = pd.read_csv('menu.csv')

# %%
nut.head(50)
# Out:
#        Category                                               Item  \
# 0     Breakfast                                       Egg McMuffin
# 1     Breakfast                                  Egg White Delight
# 2     Breakfast                                   Sausage McMuffin
# 3     Breakfast                          Sausage McMuffin with Egg
# 4     Breakfast                   Sausage McMuffin with Egg Whites
# 5     Breakfast                               Steak & Egg McMuffin
# 6     Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7     Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8     Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9     Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 10    Breakfast                  Sausage Biscuit (Regular Biscuit)
# 11    Breakfast                    Sausage Biscuit (Large Biscuit)
# 12    Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
# ...

# %%
nut.info()
#from the info we can see that there are no missing data in the dataset 
#as all the inputs in each ccolumn are all 260 non-null in number
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
nut.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
nut.duplicated().nunique()
# Out:
# 1

# %%
nut.median()
# Out:
# C:\Users\Utulu\AppData\Local\Temp\ipykernel_5368\2354636133.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nut.median()
# Calories                         340.0
# Calories from Fat                100.0
# Total Fat                         11.0
# Total Fat (% Daily Value)         17.0
# Saturated Fat                      5.0
# Saturated Fat (% Daily Value)     24.0
# Trans Fat                          0.0
# Cholesterol                       35.0
# Cholesterol (% Daily Value)       11.0
# Sodium                           190.0
# Sodium (% Daily Value)             8.0
# Carbohydrates                     44.0
# Carbohydrates (% Daily Value)     15.0
# Dietary Fiber                      1.0
# Dietary Fiber (% Daily Value)      5.0
# Sugars                            17.5
# Protein                           12.0
# ...

# %%
nut.mean()
# Out:
# C:\Users\Utulu\AppData\Local\Temp\ipykernel_5368\890173374.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nut.mean()
# Calories                         368.269231
# Calories from Fat                127.096154
# Total Fat                         14.165385
# Total Fat (% Daily Value)         21.815385
# Saturated Fat                      6.007692
# Saturated Fat (% Daily Value)     29.965385
# Trans Fat                          0.203846
# Cholesterol                       54.942308
# Cholesterol (% Daily Value)       18.392308
# Sodium                           495.750000
# Sodium (% Daily Value)            20.676923
# Carbohydrates                     47.346154
# Carbohydrates (% Daily Value)     15.780769
# Dietary Fiber                      1.630769
# Dietary Fiber (% Daily Value)      6.530769
# ...

# %%
nut1 = nut.copy()

# %%
nut1[nut1['Calories']>450].head()
# Out:
#      Category                                               Item  \
# 6   Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7   Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 9   Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
# 11  Breakfast                    Sausage Biscuit (Large Biscuit)
# 12  Breakfast         Sausage Biscuit with Egg (Regular Biscuit)
#
#       Serving Size  Calories  Calories from Fat  Total Fat  \
# 6   5.3 oz (150 g)       460                230       26.0
# 7   5.8 oz (164 g)       520                270       30.0
# 9   5.9 oz (167 g)       470                220       25.0
# 11  4.6 oz (131 g)       480                280       31.0
# 12  5.7 oz (163 g)       510                290       33.0
#
#     Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 6                          40           13.0                             65
# ...

# %%
nut_cat = nut1.groupby('Category')
nut_cat.max()
# Out:
#                                                             Item  \
# Category
# Beef & Pork                          Quarter Pounder with Cheese
# Beverages                                         Sprite (Small)
# Breakfast                              Steak, Egg & Cheese Bagel
# Chicken & Fish            Southern Style Crispy Chicken Sandwich
# Coffee & Tea                                   Sweet Tea (Small)
# Desserts                                       Strawberry Sundae
# Salads              Premium Southwest Salad with Grilled Chicken
# Smoothies & Shakes                         Vanilla Shake (Small)
# Snacks & Sides                                Small French Fries
#
#                         Serving Size  Calories  Calories from Fat  Total Fat  \
# Category
# Beef & Pork           9.5 oz (270 g)       750                380       43.0
# Beverages           6 fl oz (177 ml)       280                 20        2.5
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
nut1.set_index('Category', inplace = True)

# %%
breakfast = nut1.loc[['Breakfast']]
np.mean(breakfast)
# Out:
# C:\Users\Utulu\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# C:\Users\Utulu\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Calories                          526.666667
# Calories from Fat                 248.928571
# Total Fat                          27.690476
# Total Fat (% Daily Value)          42.666667
# Saturated Fat                      10.654762
# Saturated Fat (% Daily Value)      53.428571
# ...

# %%
beef_pork = nut1.loc[['Beef & Pork']]
beef_pork
# Out:
#                                                   Item    Serving Size  \
# Category
# Beef & Pork                                    Big Mac  7.4 oz (211 g)
# Beef & Pork                Quarter Pounder with Cheese  7.1 oz (202 g)
# Beef & Pork        Quarter Pounder with Bacon & Cheese    8 oz (227 g)
# Beef & Pork  Quarter Pounder with Bacon Habanero Ranch  8.3 oz (235 g)
# Beef & Pork                     Quarter Pounder Deluxe  8.6 oz (244 g)
# Beef & Pork         Double Quarter Pounder with Cheese   10 oz (283 g)
# Beef & Pork                                  Hamburger   3.5 oz (98 g)
# Beef & Pork                               Cheeseburger    4 oz (113 g)
# Beef & Pork                        Double Cheeseburger  5.7 oz (161 g)
# Beef & Pork                     Bacon Clubhouse Burger  9.5 oz (270 g)
# Beef & Pork                                   McDouble  5.2 oz (147 g)
# Beef & Pork                             Bacon McDouble  5.7 oz (161 g)
# ...

# %%
beverages = nut1.loc[['Beverages']]
beverages
# Out:
#                                         Item       Serving Size  Calories  \
# Category
# Beverages          Coca-Cola Classic (Small)       16 fl oz cup       140
# Beverages         Coca-Cola Classic (Medium)       21 fl oz cup       200
# Beverages          Coca-Cola Classic (Large)       30 fl oz cup       280
# Beverages          Coca-Cola Classic (Child)       12 fl oz cup       100
# Beverages                  Diet Coke (Small)       16 fl oz cup         0
# Beverages                 Diet Coke (Medium)       21 fl oz cup         0
# Beverages                  Diet Coke (Large)       30 fl oz cup         0
# Beverages                  Diet Coke (Child)       12 fl oz cup         0
# Beverages                  Dr Pepper (Small)       16 fl oz cup       140
# Beverages                 Dr Pepper (Medium)       21 fl oz cup       190
# Beverages                  Dr Pepper (Large)       30 fl oz cup       270
# ...

# %%
tea = nut1.loc[['Coffee & Tea']]
tea.head()
# Out:
#                            Item  Serving Size  Calories  Calories from Fat  \
# Category
# Coffee & Tea   Iced Tea (Small)  16 fl oz cup         0                  0
# Coffee & Tea  Iced Tea (Medium)  21 fl oz cup         0                  0
# Coffee & Tea   Iced Tea (Large)  30 fl oz cup         0                  0
# Coffee & Tea   Iced Tea (Child)  12 fl oz cup         0                  0
# Coffee & Tea  Sweet Tea (Small)  16 fl oz cup       150                  0
#
#               Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# Category
# Coffee & Tea        0.0                          0            0.0
# Coffee & Tea        0.0                          0            0.0
# Coffee & Tea        0.0                          0            0.0
# Coffee & Tea        0.0                          0            0.0
# Coffee & Tea        0.0                          0            0.0
#
#               Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# Category
# ...

# %%
shakes = nut1.loc[['Smoothies & Shakes']]
shakes.head()
# Out:
#                                                        Item  Serving Size  \
# Category
# Smoothies & Shakes   Blueberry Pomegranate Smoothie (Small)  12 fl oz cup
# Smoothies & Shakes  Blueberry Pomegranate Smoothie (Medium)  16 fl oz cup
# Smoothies & Shakes   Blueberry Pomegranate Smoothie (Large)  22 fl oz cup
# Smoothies & Shakes       Strawberry Banana Smoothie (Small)  12 fl oz cup
# Smoothies & Shakes      Strawberry Banana Smoothie (Medium)  16 fl oz cup
#
#                     Calories  Calories from Fat  Total Fat  \
# Category
# Smoothies & Shakes       220                  5        0.5
# Smoothies & Shakes       260                  5        1.0
# Smoothies & Shakes       340                 10        1.0
# Smoothies & Shakes       210                  5        0.5
# Smoothies & Shakes       250                  5        1.0
#
#                     Total Fat (% Daily Value)  Saturated Fat  \
# Category
# Smoothies & Shakes                          1            0.0
# ...

# %%
snacks = nut1.loc[['Snacks & Sides']]
snacks
# Out:
#                                                       Item    Serving Size  \
# Category
# Snacks & Sides    Chipotle BBQ Snack Wrap (Crispy Chicken)  4.6 oz (130 g)
# Snacks & Sides   Chipotle BBQ Snack Wrap (Grilled Chicken)  4.3 oz (123 g)
# Snacks & Sides   Honey Mustard Snack Wrap (Crispy Chicken)  4.3 oz (123 g)
# Snacks & Sides  Honey Mustard Snack Wrap (Grilled Chicken)  4.1 oz (116 g)
# Snacks & Sides           Ranch Snack Wrap (Crispy Chicken)  4.5 oz (128 g)
# Snacks & Sides          Ranch Snack Wrap (Grilled Chicken)  4.3 oz (121 g)
# Snacks & Sides                          Small French Fries   2.6 oz (75 g)
# Snacks & Sides                         Medium French Fries  3.9 oz (111 g)
# Snacks & Sides                          Large French Fries  5.9 oz (168 g)
# Snacks & Sides                           Kids French Fries   1.3 oz (38 g)
# Snacks & Sides                                  Side Salad   3.1 oz (87 g)
# ...

# %%
chicken_fish = nut1.loc[['Chicken & Fish']]
chicken_fish
# Out:
#                                                              Item  \
# Category
# Chicken & Fish            Premium Crispy Chicken Classic Sandwich
# Chicken & Fish           Premium Grilled Chicken Classic Sandwich
# Chicken & Fish               Premium Crispy Chicken Club Sandwich
# Chicken & Fish              Premium Grilled Chicken Club Sandwich
# Chicken & Fish          Premium Crispy Chicken Ranch BLT Sandwich
# Chicken & Fish         Premium Grilled Chicken Ranch BLT Sandwich
# Chicken & Fish            Bacon Clubhouse Crispy Chicken Sandwich
# Chicken & Fish           Bacon Clubhouse Grilled Chicken Sandwich
# Chicken & Fish             Southern Style Crispy Chicken Sandwich
# Chicken & Fish                                          McChicken
# Chicken & Fish                            Bacon Cheddar McChicken
# Chicken & Fish                      Bacon Buffalo Ranch McChicken
# Chicken & Fish                            Buffalo Ranch McChicken
# ...

# %%
Salad = nut1.loc[['Salads']]

# %%
desserts = nut1.loc[['Desserts']]
desserts.head()
# Out:
#                            Item     Serving Size  Calories  Calories from Fat  \
# Category
# Desserts        Baked Apple Pie    2.7 oz (77 g)       250                110
# Desserts  Chocolate Chip Cookie  1 cookie (33 g)       160                 70
# Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150                 50
# Desserts    Kids Ice Cream Cone      1 oz (29 g)        45                 10
# Desserts       Hot Fudge Sundae   6.3 oz (179 g)       330                 80
#
#           Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# Category
# Desserts       13.0                         19            7.0
# Desserts        8.0                         12            3.5
# Desserts        6.0                          9            2.5
# Desserts        1.5                          2            1.0
# Desserts        9.0                         14            7.0
#
#           Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# Category
# ...

# %%
Salad.reset_index(inplace = True)
Salad.drop('Category', axis = 1)
# Out:
#                                              Item     Serving Size  Calories  \
# 0     Premium Bacon Ranch Salad (without Chicken)   7.9 oz (223 g)       140
# 1   Premium Bacon Ranch Salad with Crispy Chicken     9 oz (255 g)       380
# 2  Premium Bacon Ranch Salad with Grilled Chicken   8.5 oz (241 g)       220
# 3       Premium Southwest Salad (without Chicken)   8.1 oz (230 g)       140
# 4     Premium Southwest Salad with Crispy Chicken  12.3 oz (348 g)       450
# 5    Premium Southwest Salad with Grilled Chicken  11.8 oz (335 g)       290
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                 70        7.0                         11            3.5
# 1                190       21.0                         33            6.0
# 2                 80        8.0                         13            4.0
# 3                 40        4.5                          7            2.0
# ...

# %%
fig = plt.figure(figsize = (12,8))
sns.barplot(data = Salad, y = 'Calories', x = 'Item')
# Out:
# <AxesSubplot:xlabel='Item', ylabel='Calories'>

# %%
nut_cat.max()
# Out:
#                                                             Item  \
# Category
# Beef & Pork                          Quarter Pounder with Cheese
# Beverages                                         Sprite (Small)
# Breakfast                              Steak, Egg & Cheese Bagel
# Chicken & Fish            Southern Style Crispy Chicken Sandwich
# Coffee & Tea                                   Sweet Tea (Small)
# Desserts                                       Strawberry Sundae
# Salads              Premium Southwest Salad with Grilled Chicken
# Smoothies & Shakes                         Vanilla Shake (Small)
# Snacks & Sides                                Small French Fries
#
#                         Serving Size  Calories  Calories from Fat  Total Fat  \
# Category
# Beef & Pork           9.5 oz (270 g)       750                380       43.0
# Beverages           6 fl oz (177 ml)       280                 20        2.5
# ...

# %%
tea[tea['Sodium'] == tea['Sodium'].max()]
# Out:
#                                                 Item  Serving Size  Calories  \
# Category
# Coffee & Tea                   Hot Chocolate (Large)  20 fl oz cup       540
# Coffee & Tea  Hot Chocolate with Nonfat Milk (Large)  20 fl oz cup       400
#
#               Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# Category
# Coffee & Tea                180       20.0                         31
# Coffee & Tea                 35        3.5                          6
#
#               Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  \
# Category
# Coffee & Tea           12.0                             58        0.5
# Coffee & Tea            2.5                             12        0.0
#
#               Cholesterol  Cholesterol (% Daily Value)  Sodium  \
# Category
# Coffee & Tea           60                           20     280
# Coffee & Tea           20                            7     280
#
#               Sodium (% Daily Value)  Carbohydrates  \
# Category
# ...

# %%
tea[tea['Calories'] == tea['Calories'].max()]
# Out:
#                                        Item  Serving Size  Calories  \
# Category
# Coffee & Tea  Frappé Chocolate Chip (Large)  22 fl oz cup       760
#
#               Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# Category
# Coffee & Tea                280       31.0                         48
#
#               Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  \
# Category
# Coffee & Tea           20.0                            101        1.5
#
#               Cholesterol  Cholesterol (% Daily Value)  Sodium  \
# Category
# Coffee & Tea           95                           32     200
#
#               Sodium (% Daily Value)  Carbohydrates  \
# Category
# Coffee & Tea                       8            111
#
#               Carbohydrates (% Daily Value)  Dietary Fiber  \
# Category
# Coffee & Tea                             37              1
#
#               Dietary Fiber (% Daily Value)  Sugars  Protein  \
# Category
# ...

# %%
def sodium_content(sodium):
    if sodium < 800:
        return True
    else:
        return False

# %%
# according to the fda amount of sodium  per day should be 2400 i.e 800 per meal
nut1['sodium<800'] = nut1['Sodium'].apply(sodium_content)
nut1
# Out:
#                                                                  Item  \
# Category
# Breakfast                                                Egg McMuffin
# Breakfast                                           Egg White Delight
# Breakfast                                            Sausage McMuffin
# Breakfast                                   Sausage McMuffin with Egg
# Breakfast                            Sausage McMuffin with Egg Whites
# ...                                                               ...
# Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                        Serving Size  Calories  Calories from Fat  Total Fat  \
# Category
# ...

# %%
sns.countplot(x = 'sodium<800', data = nut1)
# Out:
# <AxesSubplot:xlabel='sodium<800', ylabel='count'>

# %%
sns.countplot(x = 'sodium<800', data = breakfast)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 sns.countplot(x = 'sodium<800', data = breakfast)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3598, in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3595 elif x is not None and y is not None:
# ...

# %%
nut1.reset_index(inplace = True)

# %%
sns.histplot(x = 'Sodium', data = nut1, hue = 'sodium<800', bins = 30)
# Out:
# <AxesSubplot:xlabel='Sodium', ylabel='Count'>

# %%
sns.countplot(x = 'sodium<800', data = nut1)
# Out:
# <AxesSubplot:xlabel='sodium<800', ylabel='count'>
